# %% [markdown]
# # ETL (Extraction Transform Load) y EDA (Analitics Eploration Data )

# %% [markdown]
# ## ** **ANALISIS DE ARCHIVO BUSINESS DE LA PLATAFORMA YELP** **
# Para comenzar a analizar, primero se hizo el proceso de ETL, ya que el archivo estaba en formato "pickle", y se transformo a "csv", ademas se utilizo la libreria "gdown", para descargar desde el drive, a colab. por el tema de recursos.

# %%
import numpy as np
import pandas as pd
import ast
import warnings
import datetime
import gdown
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import warnings
#       5 import datetime
# ----> 6 import gdown
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'gdown'

# %%
# ID de la carpeta de Google Drive
id = "1jJxkUUZ9JZO2PYJ5o5nbhWrr5uzQOfJB"

# Descargar todo el contenido de la carpeta
gdown.download_folder(f"https://drive.google.com/drive/folders/{id}", quiet=False)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Retrieving folder contents
# Processing file 1dQ7KGCWY2TjacJ6s1qdgXNUcIWETK_ny business.pkl
# Processing file 1OZVxA7AJNocMxDop9AM0VRR47igR661w checkin_csv.csv
# Processing file 1YJBUdtr2yjZlm8ozk-GUoOuTPgFm5daE dfbus_csv.csv
# Processing file 1c64ZN_Zg1_vOeld_fgNFYbGM2qveuhf- dfbussnew_csv.csv
# Processing file 1rlHZHxi4BsTm6y7mSFr2RSZtCCT1QPY2 dfbussnew3_csv.csv
# Processing file 1sY_vS4oRrjEL0sVaeDxx5TdV05h85iH5 dfcheckins3_csv.csv
# Processing file 13UenKmczz-XcHyINpisnBS8tCdPi2kpT dfreview3_csv.csv
# Processing file 1OIWb7J5AGXc0fr0M9erqbnK_J_052AwO dfreviewgoo3_csv.csv
# Processing file 1zJOLUd4EXm-VsRTt5ixRYwEz2AiILy6i0K_DSKETgYQ Diagrama de Gantt
# Processing file 1Sg0aOCcTZuL0jYosy1ldBZ2795PJBV69 Diccionario de DATOS - PROY FINAL.xlsx
# Processing file 1ldlcXeuybcJjVps2HaUFPRP7dW1KCZfl EDA.ipynb
# Processing file 18UBpLSMJchsqQDuxrQWq6pYqtYtJAnv0 ETL_USER&TIP.ipynb
# Processing file 1h6rtP0S60wV3iJGmDLR8k62oJOUPET-Y review.json
# Processing file 1KsWBlcCBd2L36dwKEC2vIqnccD3rP09A tip.json
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1dQ7KGCWY2TjacJ6s1qdgXNUcIWETK_ny
# From (redirected): https://drive.google.com/uc?id=1dQ7KGCWY2TjacJ6s1qdgXNUcIWETK_ny&confirm=t&uuid=6f72cef8-938b-4202-843a-90fd200def2f
# To: /content/Proyecto_final_Henry/business.pkl
# 100%|██████████| 116M/116M [00:02<00:00, 41.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1OZVxA7AJNocMxDop9AM0VRR47igR661w
# From (redirected): https://drive.google.com/uc?id=1OZVxA7AJNocMxDop9AM0VRR47igR661w&confirm=t&uuid=5c3427f0-c448-4106-8e8f-860bd3646d5a
# To: /content/Proyecto_final_Henry/checkin_csv.csv
# 100%|██████████| 285M/285M [00:04<00:00, 64.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YJBUdtr2yjZlm8ozk-GUoOuTPgFm5daE
# To: /content/Proyecto_final_Henry/dfbus_csv.csv
# 100%|██████████| 101M/101M [00:00<00:00, 143MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1c64ZN_Zg1_vOeld_fgNFYbGM2qveuhf-
# To: /content/Proyecto_final_Henry/dfbussnew_csv.csv
# 100%|██████████| 49.5M/49.5M [00:00<00:00, 123MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rlHZHxi4BsTm6y7mSFr2RSZtCCT1QPY2
# To: /content/Proyecto_final_Henry/dfbussnew3_csv.csv
# 100%|██████████| 20.6M/20.6M [00:00<00:00, 126MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1sY_vS4oRrjEL0sVaeDxx5TdV05h85iH5
# From (redirected): https://drive.google.com/uc?id=1sY_vS4oRrjEL0sVaeDxx5TdV05h85iH5&confirm=t&uuid=c62463d8-7451-4c56-a4ac-d672b3102f14
# To: /content/Proyecto_final_Henry/dfcheckins3_csv.csv
# 100%|██████████| 628M/628M [00:05<00:00, 124MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=13UenKmczz-XcHyINpisnBS8tCdPi2kpT
# From (redirected): https://drive.google.com/uc?id=13UenKmczz-XcHyINpisnBS8tCdPi2kpT&confirm=t&uuid=e9e8d692-04fc-4a6b-865a-ac33b5dd3cc6
# To: /content/Proyecto_final_Henry/dfreview3_csv.csv
# 100%|██████████| 477M/477M [00:04<00:00, 116MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OIWb7J5AGXc0fr0M9erqbnK_J_052AwO
# To: /content/Proyecto_final_Henry/dfreviewgoo3_csv.csv
# 100%|██████████| 10.5M/10.5M [00:00<00:00, 204MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1zJOLUd4EXm-VsRTt5ixRYwEz2AiILy6i0K_DSKETgYQ
# From (redirected): https://docs.google.com/spreadsheets/d/1zJOLUd4EXm-VsRTt5ixRYwEz2AiILy6i0K_DSKETgYQ/export?format=xlsx
# To: /content/Proyecto_final_Henry/Diagrama de Gantt
# 37.2kB [00:00, 44.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Sg0aOCcTZuL0jYosy1ldBZ2795PJBV69
# To: /content/Proyecto_final_Henry/Diccionario de DATOS - PROY FINAL.xlsx
# 100%|██████████| 22.5k/22.5k [00:00<00:00, 33.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ldlcXeuybcJjVps2HaUFPRP7dW1KCZfl
# To: /content/Proyecto_final_Henry/EDA.ipynb
# 100%|██████████| 621/621 [00:00<00:00, 1.70MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18UBpLSMJchsqQDuxrQWq6pYqtYtJAnv0
# To: /content/Proyecto_final_Henry/ETL_USER&TIP.ipynb
# 100%|██████████| 548k/548k [00:00<00:00, 85.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1h6rtP0S60wV3iJGmDLR8k62oJOUPET-Y
# From (redirected): https://drive.google.com/uc?id=1h6rtP0S60wV3iJGmDLR8k62oJOUPET-Y&confirm=t&uuid=3165e1f8-5946-4281-a548-a85490e41b18
# To: /content/Proyecto_final_Henry/review.json
# 100%|██████████| 5.34G/5.34G [01:01<00:00, 87.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1KsWBlcCBd2L36dwKEC2vIqnccD3rP09A
# From (redirected): https://drive.google.com/uc?id=1KsWBlcCBd2L36dwKEC2vIqnccD3rP09A&confirm=t&uuid=ed3c4e9f-9a07-4ab0-a7c7-74634bf06cbf
# To: /content/Proyecto_final_Henry/tip.json
# 100%|██████████| 181M/181M [00:02<00:00, 83.6MB/s]
# Download completed
# ['/content/Proyecto_final_Henry/business.pkl',
#  '/content/Proyecto_final_Henry/checkin_csv.csv',
#  '/content/Proyecto_final_Henry/dfbus_csv.csv',
#  '/content/Proyecto_final_Henry/dfbussnew_csv.csv',
#  '/content/Proyecto_final_Henry/dfbussnew3_csv.csv',
#  '/content/Proyecto_final_Henry/dfcheckins3_csv.csv',
#  '/content/Proyecto_final_Henry/dfreview3_csv.csv',
#  '/content/Proyecto_final_Henry/dfreviewgoo3_csv.csv',
#  '/content/Proyecto_final_Henry/Diagrama de Gantt',
#  '/content/Proyecto_final_Henry/Diccionario de DATOS - PROY FINAL.xlsx',
#  '/content/Proyecto_final_Henry/EDA.ipynb',
#  '/content/Proyecto_final_Henry/ETL_USER&TIP.ipynb',
#  '/content/Proyecto_final_Henry/review.json',
#  '/content/Proyecto_final_Henry/tip.json']

# %%
# !ls /content/Proyecto_final_Henry/dfbus_csv.csv
# Out:
# /content/Proyecto_final_Henry/dfbus_csv.csv

# %% [markdown]
# Se utilizaron metodos y funciones para su analisis como "info()", "dtypes()", "columns", "head()", etc.
# Y tambien el uso de las librerias de PYTHON, (numpy, pandas, ast, matplotlib, datetime, etc.).

# %%
df_bus=pd.read_csv("../Carpeta_ETL/prueba1.csv")
df_bus.head()
# Out:
# C:\Users\Esteban\AppData\Local\Temp\ipykernel_7800\2888839371.py:8: DtypeWarning: Columns (14,15,16,17,18,19,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bus=pd.read_csv("../Carpeta_ETL/prueba1.csv")
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  ...  state.1 postal_code.1  \
# 0  34.426679 -119.711197    5.0             7  ...      NaN           NaN
# 1  38.551126  -90.335695    3.0            15  ...      NaN           NaN
# 2  32.223236 -110.880452    3.5            22  ...      NaN           NaN
# 3  39.955505  -75.155564    4.0            80  ...      NaN           NaN
# 4  40.338183  -75.471659    4.5            13  ...      NaN           NaN
#
#   latitude.1 longitude.1 stars.1 review_count.1 is_open.1 attributes.1  \
# 0        NaN         NaN     NaN            NaN       NaN          NaN
# 1        NaN         NaN     NaN            NaN       NaN          NaN
# 2        NaN         NaN     NaN            NaN       NaN          NaN
# 3        NaN         NaN     NaN            NaN       NaN          NaN
# 4        NaN         NaN     NaN            NaN       NaN          NaN
#
#   categories.1 hours.1
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
#
# [5 rows x 28 columns]

# %%
df_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   business_id     150346 non-null  object
#  1   name            150346 non-null  object
#  2   address         145219 non-null  object
#  3   city            150346 non-null  object
#  4   state           150343 non-null  object
#  5   postal_code     150273 non-null  object
#  6   latitude        150346 non-null  float64
#  7   longitude       150346 non-null  float64
#  8   stars           150346 non-null  float64
#  9   review_count    150346 non-null  int64
#  10  is_open         150346 non-null  int64
#  11  attributes      136602 non-null  object
#  12  categories      150243 non-null  object
#  13  hours           127123 non-null  object
#  14  business_id.1   5 non-null       object
#  15  name.1          5 non-null       object
#  16  address.1       5 non-null       object
#  17  city.1          5 non-null       object
#  18  state.1         5 non-null       object
#  19  postal_code.1   5 non-null       object
#  20  latitude.1      5 non-null       float64
#  21  longitude.1     5 non-null       float64
#  22  stars.1         5 non-null       float64
#  23  review_count.1  5 non-null       float64
#  24  is_open.1       5 non-null       float64
#  25  attributes.1    5 non-null       object
#  26  categories.1    5 non-null       object
#  27  hours.1         5 non-null       object
# dtypes: float64(8), int64(2), object(18)
# memory usage: 32.1+ MB

# %%
df_bus.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id.1', 'name.1',
#        'address.1', 'city.1', 'state.1', 'postal_code.1', 'latitude.1',
#        'longitude.1', 'stars.1', 'review_count.1', 'is_open.1', 'attributes.1',
#        'categories.1', 'hours.1'],
#       dtype='object')

# %%
df_bus.columns.tolist  # Mostrar las columnas en una lista
df_bus = df_bus.drop(columns=['business_id.1', 'name.1',
       'address.1', 'city.1', 'state.1', 'postal_code.1', 'latitude.1',
       'longitude.1', 'stars.1', 'review_count.1', 'is_open.1', 'attributes.1',
       'categories.1', 'hours.1'])  # Eliminar la columna "Unnamed: 0" y "postal_code_int"
print(df_bus.columns)
df_bus.info()
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       145219 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150273 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  float64
#  9   review_count  150346 non-null  int64
#  10  is_open       150346 non-null  int64
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 16.1+ MB

# %% [markdown]
# Vamos a analizar los elementos que son ceros de las columnas, y luego ver si la columna que puede ser un indice "business_id", contiene duplicados.

# %%
df_bus.isnull().sum()
# Out:
# business_id         0
# name                0
# address          5127
# city                0
# state               3
# postal_code        73
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      13744
# categories        103
# hours           23223
# dtype: int64

# %%
df_bus.duplicated('business_id').sum()
df_newbuss=df_bus

# %% [markdown]
# Veo que el indice principal no tiene duplicados, por ende puede ser una clave primaria y tomarla como "PRIMARY KEY" de esta entidad.

# %% [markdown]
# Cuando se analizo a simple vista la columna "attributes", se observo que habia distintas irregularidades que no se podia trabajar, debido a que habia signos de puntuacion que no me dejaba y ademas tambien los "value" eran del tipo "string" y no "bool", asi que eso se va a cambiar, tambien se observo que este atributo contiene un diccionario el cual se podria desanidar para su estudio, en forma individual.

# %%
df_newbuss.head()
df_prueba=df_newbuss

# Función para convertir los valores a diccionarios, evitando datos del tipo NaN
def safe_literal_eval(val):
    try:
        if pd.notna(val):
            return ast.literal_eval(val)
        return val
    except (ValueError, SyntaxError):
        return val  # Si ocurre error, devuelve el valor original
df_prueba['attributes'] = df_prueba['attributes'].apply(safe_literal_eval)

# Función para convertir strings 'True'/'False' a booleanos en un diccionario
def convert_strings_to_bool(d):
    if isinstance(d, dict):  # Veo si es un diccionario
        for key, value in d.items():
            if value == 'True':
                d[key] = True
            elif value == 'False':
                d[key] = False
    return d
df_prueba['attributes'] = df_prueba['attributes'].apply(convert_strings_to_bool)

# Verificar los cambios
print(df_prueba['attributes'])
# Out:
# 0                               {'ByAppointmentOnly': True}
# 1                      {'BusinessAcceptsCreditCards': True}
# 2         {'BikeParking': True, 'BusinessAcceptsCreditCa...
# 3         {'RestaurantsDelivery': False, 'OutdoorSeating...
# 4         {'BusinessAcceptsCreditCards': True, 'Wheelcha...
#                                 ...
# 150341    {'ByAppointmentOnly': False, 'RestaurantsPrice...
# 150342    {'BusinessAcceptsCreditCards': True, 'Restaura...
# 150343    {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344    {'BusinessParking': '{'garage': False, 'street...
# 150345    {'WheelchairAccessible': True, 'BusinessAccept...
# Name: attributes, Length: 150346, dtype: object

# %%
# Chequeo cuantos, diccionarios vacios y cuantos NaN hay en la columna "attributes"
empty_dicts = df_prueba['attributes'].apply(lambda x: isinstance(x, dict) and len(x) == 0).sum()
nan_values = df_prueba['attributes'].isna().sum()
print(f"Diccionarios vacíos: {empty_dicts}, NaN: {nan_values}")
new_dfbuss=df_prueba
new_dfbuss.head()
# Out:
# Diccionarios vacíos: 0, NaN: 0
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                        {'ByAppointmentOnly': True}
# 1               {'BusinessAcceptsCreditCards': True}
# 2  {'BikeParking': True, 'BusinessAcceptsCreditCa...
# 3  {'RestaurantsDelivery': False, 'OutdoorSeating...
# 4  {'BusinessAcceptsCreditCards': True, 'Wheelcha...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %% [markdown]
# Para eso me creo un diccionario por defecto, con valores "False", para cada "key". Donde esta contiene los datos relacionados a los estudiados que serian los "restaurant".

# %%
# Defino un diccionario por defecto, con los datos que necesitamos
default_dict = {'BikeParking': False, 'OutdoorSeating': False, 'HasTV': False, 'RestaurantsDelivery': False,'RestaurantsTakeOut': False,'BusinessAcceptsCreditCards': False,'RestaurantsGoodForGroups': False,'Caters': False,'BusinessAcceptsBitcoin': False, 'RestaurantsTableService': False,'DriveThru': True, 'ByAppointmentOnly': False, 'WheelchairAccessible':False}
df_prueba['attributes'] = df_prueba['attributes'].apply(lambda x: default_dict if (x == {} or pd.isna(x)) else x)
df_newbuss=df_prueba

# Veo los ultimos 5 elementos para ver si se ha reemplazado correctamente
df_prueba.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                        {'ByAppointmentOnly': True}
# 1               {'BusinessAcceptsCreditCards': True}
# 2  {'BikeParking': True, 'BusinessAcceptsCreditCa...
# 3  {'RestaurantsDelivery': False, 'OutdoorSeating...
# 4  {'BusinessAcceptsCreditCards': True, 'Wheelcha...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
# Corroboro que me haya cambiado todos los datos, por el diccionario por defecto
empty_dicts = new_dfbuss['attributes'].apply(lambda x: isinstance(x, dict) and len(x) == 0).sum()
nan_values = new_dfbuss['attributes'].isna().sum()

print(f"Diccionarios vacíos: {empty_dicts}, NaN: {nan_values}")
# Out:
# Diccionarios vacíos: 0, NaN: 0

# %% [markdown]
# Vamos a aplanar el diccionario este, donde las clave seran las nuevas columnas y los valores las filas.
# Para poder analizar bien, cada uno de sus valores y si me hacen representabilidad en la toma de desiciones.

# %%
# Aplano el diccionario de attributes
attributes_flat = pd.json_normalize(new_dfbuss['attributes'])
df_flattened = pd.concat([new_dfbuss.drop('attributes', axis=1), attributes_flat], axis=1)
df_flattened.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  ...  AcceptsInsurance  \
# 0  34.426679 -119.711197    5.0             7  ...               NaN
# 1  38.551126  -90.335695    3.0            15  ...               NaN
# 2  32.223236 -110.880452    3.5            22  ...               NaN
# 3  39.955505  -75.155564    4.0            80  ...               NaN
# 4  40.338183  -75.471659    4.5            13  ...               NaN
#
#   BestNights BYOB Corkage BYOBCorkage HairSpecializesIn Open24Hours  \
# 0        NaN  NaN     NaN         NaN               NaN         NaN
# 1        NaN  NaN     NaN         NaN               NaN         NaN
# 2        NaN  NaN     NaN         NaN               NaN         NaN
# 3        NaN  NaN     NaN         NaN               NaN         NaN
# 4        NaN  NaN     NaN         NaN               NaN         NaN
#
#   RestaurantsCounterService AgesAllowed DietaryRestrictions
# 0                       NaN         NaN                 NaN
# 1                       NaN         NaN                 NaN
# 2                       NaN         NaN                 NaN
# 3                       NaN         NaN                 NaN
# 4                       NaN         NaN                 NaN
#
# [5 rows x 52 columns]

# %%
df_flattened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   business_id                 150346 non-null  object
#  1   name                        150346 non-null  object
#  2   address                     150346 non-null  object
#  3   city                        150346 non-null  object
#  4   state                       150343 non-null  object
#  5   postal_code                 150273 non-null  object
#  6   latitude                    150346 non-null  float64
#  7   longitude                   150346 non-null  float64
#  8   stars                       150346 non-null  float64
#  9   review_count                150346 non-null  int64
#  10  is_open                     150346 non-null  int64
#  11  categories                  150243 non-null  object
#  12  hours                       127123 non-null  object
#  13  ByAppointmentOnly           56083 non-null   object
#  14  BusinessAcceptsCreditCards  133509 non-null  object
#  15  BikeParking                 86382 non-null   object
#  16  RestaurantsPriceRange2      85314 non-null   object
#  17  CoatCheck                   5584 non-null    object
#  18  RestaurantsTakeOut          73601 non-null   object
#  19  RestaurantsDelivery         70026 non-null   object
#  20  Caters                      53871 non-null   object
#  21  WiFi                        56914 non-null   object
#  22  BusinessParking             91085 non-null   object
#  23  WheelchairAccessible        42697 non-null   object
#  24  HappyHour                   15171 non-null   object
#  25  OutdoorSeating              62546 non-null   object
#  26  HasTV                       58828 non-null   object
#  27  RestaurantsReservations     45247 non-null   object
#  28  DogsAllowed                 18284 non-null   object
#  29  Alcohol                     43189 non-null   object
#  30  GoodForKids                 53375 non-null   object
#  31  RestaurantsAttire           39255 non-null   object
#  32  Ambience                    44279 non-null   object
#  33  RestaurantsTableService     33726 non-null   object
#  34  RestaurantsGoodForGroups    57914 non-null   object
#  35  DriveThru                   21504 non-null   object
#  36  BusinessAcceptsBitcoin      31174 non-null   object
#  37  NoiseLevel                  37993 non-null   object
#  38  GoodForMeal                 29087 non-null   object
#  39  Smoking                     4567 non-null    object
#  40  Music                       7521 non-null    object
#  41  GoodForDancing              4628 non-null    object
#  42  AcceptsInsurance            5713 non-null    object
#  43  BestNights                  5694 non-null    object
#  44  BYOB                        4451 non-null    object
#  45  Corkage                     3553 non-null    object
#  46  BYOBCorkage                 1444 non-null    object
#  47  HairSpecializesIn           1065 non-null    object
#  48  Open24Hours                 39 non-null      object
#  49  RestaurantsCounterService   19 non-null      object
#  50  AgesAllowed                 129 non-null     object
#  51  DietaryRestrictions         31 non-null      object
# dtypes: float64(3), int64(2), object(47)
# memory usage: 59.6+ MB

# %%
columnas_a_analizar = ['BikeParking', 'OutdoorSeating', 'HasTV', 'RestaurantsDelivery','RestaurantsTakeOut','BusinessAcceptsCreditCards','RestaurantsGoodForGroups','BusinessAcceptsBitcoin', 'RestaurantsTableService','DriveThru', 'ByAppointmentOnly', 'WheelchairAccessible']  # Diccionario por defecto
df_seleccionado = df_flattened[columnas_a_analizar]
df_seleccionado.head()
# Out:
#   BikeParking OutdoorSeating  HasTV RestaurantsDelivery RestaurantsTakeOut  \
# 0         NaN            NaN    NaN                 NaN                NaN
# 1         NaN            NaN    NaN                 NaN                NaN
# 2        True          False  False               False              False
# 3        True          False    NaN               False               True
# 4        True            NaN    NaN                 NaN               True
#
#   BusinessAcceptsCreditCards RestaurantsGoodForGroups BusinessAcceptsBitcoin  \
# 0                        NaN                      NaN                    NaN
# 1                       True                      NaN                    NaN
# 2                       True                      NaN                    NaN
# 3                      False                      NaN                    NaN
# 4                       True                      NaN                    NaN
#
#   RestaurantsTableService DriveThru ByAppointmentOnly WheelchairAccessible
# 0                     NaN       NaN              True                  NaN
# 1                     NaN       NaN               NaN                  NaN
# 2                     NaN       NaN             False                 True
# 3                     NaN       NaN             False                  NaN
# 4                     NaN       NaN               NaN                 True

# %%
print(len(df_seleccionado))
# Out:
# 150346

# %%
df_seleccionado.isnull().sum()
# Out:
# BikeParking                    63964
# OutdoorSeating                 87800
# HasTV                          91518
# RestaurantsDelivery            80320
# RestaurantsTakeOut             76745
# BusinessAcceptsCreditCards     16837
# RestaurantsGoodForGroups       92432
# BusinessAcceptsBitcoin        119172
# RestaurantsTableService       116620
# DriveThru                     128842
# ByAppointmentOnly              94263
# WheelchairAccessible          107649
# dtype: int64

# %%
df_attr=df_seleccionado

# %%
# Contar los valores NaN en las columnas seleccionadas
valorNan= df_seleccionado.isna().sum()

# Crear el diagrama de barras para NaN
plt.figure(figsize=(14, 6))
valorNan.plot(kind='bar', color='skyblue')
plt.title('Cantidad de valores NaN por columna')
plt.xlabel('Columnas')
plt.ylabel('Número de valores NaN')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# De acuerdo a esta grafica, podemos notar, que hay muchas columnas que tienen mas del 50% de valores nulos.
# De todas estas columnas nos vamos a quedar con las 6 mejores, osea las que menos datos NaN tengan.

# %%
# Contar valores True y False por columna
true_valores = df_seleccionado.apply(lambda x: (x == True).sum())
false_valores = df_seleccionado.apply(lambda x: (x == False).sum())

# Crear el diagrama de barras apiladas
plt.figure(figsize=(12, 6))
plt.bar(df_seleccionado.columns, true_valores, label='True', color='green')
plt.bar(df_seleccionado.columns, false_valores, bottom=true_valores, label='False', color='red')

plt.title('Distribución de valores booleanos por columna')
plt.xlabel('Columnas')
plt.ylabel('Cantidad de valores')
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %% [markdown]
# De acuedo a los graficos de diagrama de barra, y el de acumulada, se podria analizar que son pocas los attributos que pueden tener influencia para el estudio de las mejoras en ralacion al negocio.

# %%
nan_counts = df_attr.isna().sum()
columns_least_nan = nan_counts.sort_values().index[:5]
# Seleccionar las 5 columnas que tienen menos valores NaN
df_selected = df_attr[columns_least_nan]
# Agregar estas 5 columnas seleccionadas al DataFrame original y crear un nuevo DataFrame con esas columnas incluidas
df_combined = pd.concat([df_prueba, df_selected], axis=1)
# Verificar el DataFrame resultante con las 5 columnas agregadas
df_combined.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                        {'ByAppointmentOnly': True}
# 1               {'BusinessAcceptsCreditCards': True}
# 2  {'BikeParking': True, 'BusinessAcceptsCreditCa...
# 3  {'RestaurantsDelivery': False, 'OutdoorSeating...
# 4  {'BusinessAcceptsCreditCards': True, 'Wheelcha...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours  \
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
#
#   BusinessAcceptsCreditCards BikeParking RestaurantsTakeOut  \
# 0                        NaN         NaN                NaN
# 1                       True         NaN                NaN
# 2                       True        True              False
# 3                      False        True               True
# 4                       True        True               True
#
#   RestaurantsDelivery OutdoorSeating
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2               False          False
# 3               False          False
# 4                 NaN            NaN

# %%
df_sinattr = df_combined.drop('attributes', axis=1)
df_sinattr.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours  \
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
#
#   BusinessAcceptsCreditCards BikeParking RestaurantsTakeOut  \
# 0                        NaN         NaN                NaN
# 1                       True         NaN                NaN
# 2                       True        True              False
# 3                      False        True               True
# 4                       True        True               True
#
#   RestaurantsDelivery OutdoorSeating
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2               False          False
# 3               False          False
# 4                 NaN            NaN

# %%
pd.set_option('display.max_rows', None)  # Para ver todas las filas
pd.set_option('display.max_colwidth', None)  # Para no truncar el contenido de las 

# Visualizar la columna 'categories'
print(df_sinattr['categories'].head())
# Out:
# 0    Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists
# 1                                Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services
# 2                            Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores
# 3                                                         Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
# 4                                                                                     Brewpubs, Breweries, Food
# Name: categories, dtype: object

# %%
df_sinattr.head()
df_sinattr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   business_id                 150346 non-null  object
#  1   name                        150346 non-null  object
#  2   address                     145219 non-null  object
#  3   city                        150346 non-null  object
#  4   state                       150343 non-null  object
#  5   postal_code                 150273 non-null  object
#  6   latitude                    150346 non-null  float64
#  7   longitude                   150346 non-null  float64
#  8   stars                       150346 non-null  float64
#  9   review_count                150346 non-null  int64
#  10  is_open                     150346 non-null  int64
#  11  categories                  150243 non-null  object
#  12  hours                       127123 non-null  object
#  13  BusinessAcceptsCreditCards  133509 non-null  object
#  14  BikeParking                 86382 non-null   object
#  15  RestaurantsTakeOut          73601 non-null   object
#  16  RestaurantsDelivery         70026 non-null   object
#  17  OutdoorSeating              62546 non-null   object
# dtypes: float64(3), int64(2), object(13)
# memory usage: 20.6+ MB

# %% [markdown]
# Al igual que se hizo con la columna "attributes", vamos a hacer con lo la columna "categories", esta no es un diccionario sino una lista de categorias que abarca el negocio.
# Esta tambien se va a analizar, para saber que tipos de categorias hay mas de cada tipo de comidas.

# %%
df_sinattr['categories'].head()
df_buscat=df_sinattr
# Out:
# 0    Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists
# 1                                Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services
# 2                            Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores
# 3                                                         Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
# 4                                                                                     Brewpubs, Breweries, Food
# Name: categories, dtype: object

# %%
pd.set_option('display.max_rows', None)  # Para ver todas las filas
pd.set_option('display.max_colwidth', None)  # Para no truncar el contenido de las celdas

# Filtrar las filas que contienen la palabra "Restaurant" en la columna 'categories'
df_resta = df_buscat[df_buscat['categories'].str.contains('Restaurant', case=False, na=False)]
total=len(df_resta['categories'])
# Definir los tipos de comidas que queremos analizar
tipos_comida = ['Italian', 'Greek', 'Japanese', 'American', 'Korean', 'Mexican','Pizza','Hot Dogs','Fast Food','Food','Burgers']
# Inicializar un diccionario para contar la cantidad de restaurantes de cada tipo
conteo_comidas = {comida: 0 for comida in tipos_comida}
conteo_comidas['Otras'] = 0  # Para contar el resto de tipos de comida

# Contar la cantidad de restaurantes de cada tipo de comida
for categories in df_resta['categories']:
    encontrado = False
    for comida in tipos_comida:
        if comida in categories:
            conteo_comidas[comida] += 1
            encontrado = True
            break
    if not encontrado:
        conteo_comidas['Otras'] += 1

plt.figure(figsize=(7, 4))
bars = plt.bar(conteo_comidas.keys(), conteo_comidas.values(), color='skyblue')

for bar in bars:
    height = bar.get_height()  
    plt.text(bar.get_x() + bar.get_width() / 2, height,   
             f'{int(height)}',                           
             ha='center', va='bottom')                   
# Configuraciones del gráfico
plt.xlabel('Tipo de comida')
plt.ylabel('Cantidad de restaurantes')
plt.title('Cantidad de restaurantes por tipo de comida')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En esta grafica se vee que la categoria que mas restaurantes tiene es la de comidas americanas con u total de 12356 cant de restaurantes.
# Tambien se puede analizar que el consumo de comidas chatarras como (pizzas, hot dogs, comidas rapidas, hamburguesas, etc), tambien hay muchos lugares que ofrecen este tipo de comidas.
# Y los resutarantes italianos como mexicanos tambien hay buena cantidad.
# Pero la eleccion de nosotros gracia a los estudios realizados fue RESTAURANT AMERICANOS.

# %% [markdown]
# Como nuestro estudio fue elegir el estado de FLORIDA, entonces veremos y analizaremos cual de los estados, tiene mas registros.
# Para luego poder hacer alguna comparacion en relacion a los datos estudiados.

# %%
df_buscat.shape
# Out:
# (150346, 18)

# %%
# Ciudad que más se repite
ciudad_mas_frecuente = df_resta['city'].value_counts().idxmax()
ciudad_repeticiones = df_resta['city'].value_counts().max()

# Estado que más se repite
estado_mas_frecuente = df_resta['state'].value_counts().idxmax()
estado_repeticiones = df_resta['state'].value_counts().max()

# Mostrar los resultados
print(f"La ciudad que más se repite es: {ciudad_mas_frecuente} con {ciudad_repeticiones} ocurrencias.")
print(f"El estado que más se repite es: {estado_mas_frecuente} con {estado_repeticiones} ocurrencias.")
# Out:
# La ciudad que más se repite es: Philadelphia con 5854 ocurrencias.
# El estado que más se repite es: PA con 11682 ocurrencias.

# %%
df_busshs=df_buscat
# Filtrar los registros donde el estado sea "FL" y la columna 'categories' contenga "Restaurant"
restaurantes_fl = df_busshs[(df_busshs['state'] == 'FL') & (df_busshs['categories'].str.contains('American', case=False, na=False))]
# Mostrar la cantidad de registros que cumplen con las condiciones
cantidad_restaurantes_fl = len(restaurantes_fl)
# Mostrar los primeros registros para verificar el filtro
print(f"Cantidad de restaurantes en FLORIDA, de TIPOS DE COMIDAS AMERICANAS: {cantidad_restaurantes_fl}")
# Out:
# Cantidad de restaurantes en FLORIDA, de TIPOS DE COMIDAS AMERICANAS: 2271

# %%
# Filtrar registros donde 'categories' contiene "Restaurant" y "American"
filtro_restaurantes_american = df_busshs[df_busshs['categories'].str.contains('Restaurant', case=False, na=False) &
                                  df_busshs['categories'].str.contains('American', case=False, na=False)]
# Contar la cantidad de registros por estado
conteo_por_estado = filtro_restaurantes_american['state'].value_counts()
# Seleccionar los 5 estados con más registros
top_5_estados = conteo_por_estado.head(5)
# Crear el gráfico de barras
plt.figure(figsize=(8,5))
barras = top_5_estados.plot(kind='bar', color='skyblue')
# Añadir los valores a cada barra
for i, valor in enumerate(top_5_estados):
    plt.text(i, valor + 10, str(valor), ha='center', va='bottom', fontsize=12)
# Personalizar el gráfico
plt.title('Top 5 Estados con más Restaurantes de Comida Americana')
plt.xlabel('Estado')
plt.ylabel('Cantidad de Restaurantes')
plt.xticks(rotation=0)
# Mostrar el gráfico
plt.show()

# %% [markdown]
# Aca se realiza el filtrado y la grafica, para demostrar, lo de la eleccion del estado de "FLORIDA - 2271", ya que es uno de los de mayor cantidad de registros tenemos. Despues del estado de PHILADELPIA, con un total de 2899, pero en el estdo de FLORIDA esta hoy en dia mejorando debido al deporte del FUTBOL por MESSI, ya que el se encuentra en el club de MIAMI.

# %%
df_busshs['hours'].tail()
# Out:
# 150341    {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:30', 'Wednesday': '10:0-19:30', 'Thursday': '10:0-19:30', 'Friday': '10:0-19:30', 'Saturday': '10:0-17:30', 'Sunday': '11:0-17:0'}
# 150342       {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:30', 'Wednesday': '9:30-17:30', 'Thursday': '9:30-17:30', 'Friday': '9:30-17:30', 'Saturday': '9:0-17:0', 'Sunday': '0:0-16:0'}
# 150343                                                                                                                                                                                NaN
# 150344                {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', 'Wednesday': '9:0-20:0', 'Thursday': '9:0-20:0', 'Friday': '9:0-20:0', 'Saturday': '9:0-17:0', 'Sunday': '10:0-17:0'}
# 150345                                                        {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19:0', 'Thursday': '12:0-19:0', 'Friday': '12:0-19:0', 'Saturday': '12:0-19:0'}
# Name: hours, dtype: object

# %% [markdown]
# Con la columna de horas, se hizo un analisis similar a las columnas anteriores, ya que tambien tienen un formato de diccionario, pero tambien estan mal normalizados e inicializados.
# es por eso como este dato hace referencia a la apertura y cierre del negocio, vamos a crear nuevas columnas de acuerdo a esos datos

# %%
# Reemplazar horarios '0:0-0:0' por NaN
df_busshs.replace({'0:0-0:0': np.nan}, inplace=True)
# Función para procesar la columna 'hours' y crear nuevas columnas por día
def process_hours(row, idx):
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    # Verificar si row es un diccionario
    if isinstance(row, str):
        try:
            hours_dict = eval(row)  # Convertir la cadena a un diccionario
        except Exception:
            return  # Si no se puede convertir, salir
    else:
        return  # Si no es válido, salir
    for day in days:
        if day in hours_dict:
            open_time, close_time = hours_dict[day].split('-')
            df_busshs.loc[idx, f'{day}_open'] = open_time
            df_busshs.loc[idx, f'{day}_close'] = close_time
        else:
            df_busshs.loc[idx, f'{day}_open'] = np.nan
            df_busshs.loc[idx, f'{day}_close'] = np.nan

# Aplicar la función a la columna 'hours'
for idx, row in df_busshs['hours'].items():  # Cambiado a items()
    process_hours(row, idx)
# Contar cuántos negocios están abiertos al menos un día de la semana
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
open_counts = {day: df_busshs[f'{day}_open'].notna().sum() for day in days}

# Crear un gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(open_counts.keys(), open_counts.values(), color='skyblue')
# Agregar etiquetas y título
plt.xlabel('Día de la Semana')
plt.ylabel('Número de Restaurantes Abiertos')
plt.title('Cantidad de Restaurantes abiertos por Día de la Semana')
# Mostrar la cantidad de negocios encima de cada barra
for day, count in open_counts.items():
    plt.text(day, count, str(count), ha='center', va='bottom')
# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Esteban\AppData\Local\Temp\ipykernel_7800\686789445.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8:0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_busshs.loc[idx, f'{day}_open'] = open_time
# C:\Users\Esteban\AppData\Local\Temp\ipykernel_7800\686789445.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22:0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_busshs.loc[idx, f'{day}_close'] = close_time

# %%
df_busshs.head()
df_busshs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   business_id                 150346 non-null  object
#  1   name                        150346 non-null  object
#  2   address                     145219 non-null  object
#  3   city                        150346 non-null  object
#  4   state                       150343 non-null  object
#  5   postal_code                 150273 non-null  object
#  6   latitude                    150346 non-null  float64
#  7   longitude                   150346 non-null  float64
#  8   stars                       150346 non-null  float64
#  9   review_count                150346 non-null  int64
#  10  is_open                     150346 non-null  int64
#  11  categories                  150243 non-null  object
#  12  hours                       127123 non-null  object
#  13  BusinessAcceptsCreditCards  133509 non-null  object
#  14  BikeParking                 86382 non-null   object
#  15  RestaurantsTakeOut          73601 non-null   object
#  16  RestaurantsDelivery         70026 non-null   object
#  17  OutdoorSeating              62546 non-null   object
#  18  Monday_open                 114474 non-null  object
#  19  Monday_close                114474 non-null  object
#  20  Tuesday_open                120631 non-null  object
#  21  Tuesday_close               120631 non-null  object
#  22  Wednesday_open              123771 non-null  object
#  23  Wednesday_close             123771 non-null  object
#  24  Thursday_open               125198 non-null  object
#  25  Thursday_close              125198 non-null  object
#  26  Friday_open                 124999 non-null  object
#  27  Friday_close                124999 non-null  object
#  28  Saturday_open               110770 non-null  object
#  29  Saturday_close              110770 non-null  object
#  30  Sunday_open                 81172 non-null   object
#  31  Sunday_close                81172 non-null   object
# dtypes: float64(3), int64(2), object(27)
# memory usage: 36.7+ MB

# %%
# Convierte las columnas de apertura y cierre a formato de tiempo
df_busshs['Monday_open'] = pd.to_datetime(df_busshs['Monday_open'], format='%H:%M', errors='coerce')
df_busshs['Monday_close'] = pd.to_datetime(df_busshs['Monday_close'], format='%H:%M', errors='coerce')
df_busshs['Tuesday_open'] = pd.to_datetime(df_busshs['Tuesday_open'], format='%H:%M', errors='coerce')
df_busshs['Tuesday_close'] = pd.to_datetime(df_busshs['Tuesday_close'], format='%H:%M', errors='coerce')
df_busshs['Wednesday_open'] = pd.to_datetime(df_busshs['Wednesday_open'], format='%H:%M', errors='coerce')
df_busshs['Wednesday_close'] = pd.to_datetime(df_busshs['Wednesday_close'], format='%H:%M', errors='coerce')
df_busshs['Thursday_open'] = pd.to_datetime(df_busshs['Thursday_open'], format='%H:%M', errors='coerce')
df_busshs['Thursday_close'] = pd.to_datetime(df_busshs['Thursday_close'], format='%H:%M', errors='coerce')
df_busshs['Friday_open'] = pd.to_datetime(df_busshs['Friday_open'], format='%H:%M', errors='coerce')
df_busshs['Friday_close'] = pd.to_datetime(df_busshs['Friday_close'], format='%H:%M', errors='coerce')
df_busshs['Saturday_open'] = pd.to_datetime(df_busshs['Saturday_open'], format='%H:%M', errors='coerce')
df_busshs['Saturday_close'] = pd.to_datetime(df_busshs['Saturday_close'], format='%H:%M', errors='coerce')
df_busshs['Sunday_open'] = pd.to_datetime(df_busshs['Sunday_open'], format='%H:%M', errors='coerce')
df_busshs['Sunday_close'] = pd.to_datetime(df_busshs['Sunday_close'], format='%H:%M', errors='coerce')

df_busshs['Monday_hours'] = (df_busshs['Monday_close'] - df_busshs['Monday_open']).dt.total_seconds() / 3600  # En horas
df_busshs['Tuesday_hours'] = (df_busshs['Tuesday_close'] - df_busshs['Tuesday_open']).dt.total_seconds() / 3600
df_busshs['Wednesday_hours'] = (df_busshs['Wednesday_close'] - df_busshs['Wednesday_open']).dt.total_seconds() / 3600
df_busshs['Thursday_hours'] = (df_busshs['Thursday_close'] - df_busshs['Thursday_open']).dt.total_seconds() / 3600
df_busshs['Friday_hours'] = (df_busshs['Friday_close'] - df_busshs['Friday_open']).dt.total_seconds() / 3600
df_busshs['Saturday_hours'] = (df_busshs['Saturday_close'] - df_busshs['Saturday_open']).dt.total_seconds() / 3600
df_busshs['Sunday_hours'] = (df_busshs['Sunday_close'] - df_busshs['Sunday_open']).dt.total_seconds() / 3600

# Convertir las horas de apertura y cierre a tipo datetime
for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
    df_busshs[f'{day}_open'] = pd.to_datetime(df_busshs[f'{day}_open'], format='%H:%M')
    df_busshs[f'{day}_close'] = pd.to_datetime(df_busshs[f'{day}_close'], format='%H:%M')

# Calcular las horas de apertura para cada día
for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
    # Asegurarse de que los tiempos son del tipo adecuado
    df_busshs[f'{day}_hours'] = (df_busshs[f'{day}_close'] - df_busshs[f'{day}_open']).dt.total_seconds() / 3600  # En horas

# Crear un nuevo DataFrame solo con las horas
df_hours = df_busshs[[f'{day}_hours' for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']]]
df_hours.columns = ['Monday_hours', 'Tuesday_hours', 'Wednesday_hours', 'Thursday_hours', 'Friday_hours', 'Saturday_hours', 'Sunday_hours']
# Visualización de horas promedio

# Calcular las horas promedio
average_hours = df_hours.mean()

# Crear gráfico de barras
average_hours.plot(kind='bar', color='skyblue')
plt.title('Horas promedio de apertura por día')
plt.ylabel('Duración (horas)')
plt.xlabel('Días de la semana')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.heatmap(df_hours.corr(), annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlación de horas de apertura entre días')
plt.show()

# %% [markdown]
# En el siguiente grafico de correlacion, analizamos que los dias de martes a jueves, se podria decir que hay bastantes negocios que abren a la misma hora, y que los negocios mas tempranos abren los viernes y sabados debido a que estos dias hay mas concurrencias.

# %%
df_busshs.to_csv('../Carpeta_ETL/dfbusinessYELP3_listo.csv')

# %% [markdown]
# # **ANALISIS DE ETL Y EDA DE CHECKIN.JSON**
# Este fue el mas facil de los archivos para analizar, ya que estaba en formato JSON, pero para trabajarlo mejor se lo transformo a "csv".
# Este archivo hace referencia a los checkin del negocio, donde almacena el id del negocio y a que hora fue el checkin.
# Al igual que los otros archivos, se utilizan los mismos recursos de herramientas y las mismas librerias, cargadas en el archivo "requirements.txt".

# %%
pd.set_option('display.max_rows', None)  # Para ver todas las filas
pd.set_option('display.max_colwidth', None)  # Para no truncar el contenido de las celdas
df_check=pd.read_csv("../Carpeta_ETL/checkin_csv.csv")
df_check.head()
